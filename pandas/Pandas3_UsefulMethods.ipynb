# %% [markdown]
# # Pandasda sık kullanılan Fonksiyon ve Metodlar

# %% [markdown]
# Bu kısımda pandasda bulunan bazı built-in function ve methodları öğreneceğiz. Bu öğrendiklerimiz elbette buz dağının görünen kısmı. Daha gösteremediğim pek çok fonksiyon ve method vardır. Bütün fonksiyon ve methodları görebilmek için bu [dökümantasyon](https://pandas.pydata.org/pandas-docs/stable/reference/index.html) incelenebilir.
# İlerleyen aşamalarda daha fazla fonksiyon ve method göreceğiz. Şidilik göreceğimiz fonksiyon ve methodlar :
#
# * [apply() method](#apply_method)
# * [apply() with a function](#apply_function)
# * [apply() with a lambda expression](#apply_lambda)
# * [apply() on multiple columns](#apply_multiple)
# * [describe()](#describe)
# * [sort_values()](#sort)
# * [corr()](#corr)
# * [idxmin and idxmax](#idx)
# * [value_counts()](#v_c)
# * [replace()](#replace)
# * [unique and nunique()](#uni)
# * [map()](#map)
# * [duplicated and drop_duplicates()](#dup)
# * [between()](#bet)
# * [sample()](#sample)
# * [nlargest()](#n)

# %% [markdown]
# dk 20 de kaldım pandas3

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('tips.csv')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %% [markdown]
# ## .apply() Methodu

# %%
# .apply() methodu bir series ya da dataframe'in sütunlarındaki değelerin hepsine bir anda bir fonksiyon'u uygulamaya yarar.
# Arka planında for döngüsü çalışır dolayısıyla çok hızlı değildir. Performans açısından vektörize edilmiş işlemleri uygulamak daha faydalıdır.
# Özellikle vektörize edilmiş işlemler oldukça hızlı çalışır ve for döngüsü kullanımını minimize eder.
# Ancak diğer taraftan .apply() methodunu kullanmak oldukça okunaklıdır. Başlangıçta kolaydır ve her duruma uygulanabilir. Ancak vektörize işlemler bazı durumlarda yapılamayabilir.

# %%
# Amaç : CC Number sütunundaki değerlerin son 4 rakamını almak ve CC Number sütununu bu şekilde güncellemek.

# %% [markdown]
# ## 1.Yol(apply)

# %%
def son4(x):
  return str(x)[-4:]

# %%
df['CC Number'] = df['CC Number'].apply(son4)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name CC Number Payment ID
# 0  Christy Cunningham      3410    Sun2959
# 1      Douglas Tucker      9230    Sun4608
# 2      Travis Walters      1322    Sun4458
# 3    Nathaniel Harris      5994    Sun5260
# 4        Tonya Carter      7221    Sun2251

# %% [markdown]
# ## 2.Yol(lambda)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name CC Number Payment ID
# 0  Christy Cunningham      3410    Sun2959
# 1      Douglas Tucker      9230    Sun4608
# 2      Travis Walters      1322    Sun4458
# 3    Nathaniel Harris      5994    Sun5260
# 4        Tonya Carter      7221    Sun2251

# %%
df['CC Number'] = df['CC Number'].apply(lambda x : str(x)[-3:])

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name CC Number Payment ID
# 0  Christy Cunningham       410    Sun2959
# 1      Douglas Tucker       230    Sun4608
# 2      Travis Walters       322    Sun4458
# 3    Nathaniel Harris       994    Sun5260
# 4        Tonya Carter       221    Sun2251

# %% [markdown]
# ## 3.Yol (Vektorized)(En hızlısı bu)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name CC Number Payment ID
# 0  Christy Cunningham       410    Sun2959
# 1      Douglas Tucker       230    Sun4608
# 2      Travis Walters       322    Sun4458
# 3    Nathaniel Harris       994    Sun5260
# 4        Tonya Carter       221    Sun2251

# %%
df['CC Number'].astype(str).str[-2:] # Vektörize edilmiş işlem
# Out:
# 0      10
# 1      30
# 2      22
# 3      94
# 4      21
#        ..
# 239    42
# 240    04
# 241    96
# 242    50
# 243    39
# Name: CC Number, Length: 244, dtype: object

# %%
## Amaç : 10 dolardan az ödediyse $ , 10 dolar ile 30 dolar arasında ödediyse $$ ,
# 30 dolardan fazla ödediyse $$$ işareti bulunan Fiyat Kategorisi adında bir sütun oluşturun

# %% [markdown]
# ## 1.Yol

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name CC Number Payment ID
# 0  Christy Cunningham       410    Sun2959
# 1      Douglas Tucker       230    Sun4608
# 2      Travis Walters       322    Sun4458
# 3    Nathaniel Harris       994    Sun5260
# 4        Tonya Carter       221    Sun2251

# %%
def fiyat_kategori(x):
  if x < 10 :
    return '$'
  elif 10 <= x < 30 :
    return '$$'
  else :
    return '$$$'

# %%
df['Fiyat_Kategorisi'] = df['total_bill'].apply(fiyat_kategori)

# %%
df['total_bill'].apply(fiyat_kategori).value_counts()
# Out:
# total_bill
# $$     195
# $$$     32
# $       17
# Name: count, dtype: int64

# %%
df.head(13)
# Out:
#     total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0        16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1        10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2        21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3        23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4        24.59  3.61  Female     No  Sun  Dinner     4              6.15
# 5        25.29  4.71    Male     No  Sun  Dinner     4              6.32
# 6         8.77  2.00    Male     No  Sun  Dinner     2              4.38
# 7        26.88  3.12    Male     No  Sun  Dinner     4              6.72
# 8        15.04  1.96    Male     No  Sun  Dinner     2              7.52
# 9        14.78  3.23    Male     No  Sun  Dinner     2              7.39
# 10       10.27  1.71    Male     No  Sun  Dinner     2              5.14
# 11       35.26  5.00  Female     No  Sun  Dinner     4              8.82
# 12       15.42  1.57    Male     No  Sun  Dinner     2              7.71
#
#             Payer Name CC Number Payment ID Fiyat_Kategorisi
# 0   Christy Cunningham       410    Sun2959               $$
# 1       Douglas Tucker       230    Sun4608               $$
# 2       Travis Walters       322    Sun4458               $$
# 3     Nathaniel Harris       994    Sun5260               $$
# 4         Tonya Carter       221    Sun2251               $$
# 5           Erik Smith       882    Sun9679               $$
# 6   Kristopher Johnson       344    Sun5985                $
# 7          Robert Buck       092    Sun8157               $$
# 8      Joseph Mcdonald       377    Sun6820               $$
# 9        Jerome Abbott       786    Sun3775               $$
# 10       William Riley       219    Sun2546               $$
# 11        Diane Macias       969    Sun6686              $$$
# 12     Chad Harrington       932    Sun1300               $$

# %% [markdown]
# ## 2.Yol

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name CC Number Payment ID Fiyat_Kategorisi
# 0  Christy Cunningham       410    Sun2959               $$
# 1      Douglas Tucker       230    Sun4608               $$
# 2      Travis Walters       322    Sun4458               $$
# 3    Nathaniel Harris       994    Sun5260               $$
# 4        Tonya Carter       221    Sun2251               $$

# %%
df['Fiyat_Kategorisi'] = df['total_bill'].apply(lambda x : '$' if x < 10 else ('$$' if 10 <= x < 30 else '$$$'))

# %%
df.sample(10)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 169       10.63  2.00  Female    Yes   Sat  Dinner     2              5.32
# 162       16.21  2.00  Female     No   Sun  Dinner     3              5.40
# 199       13.51  2.00    Male    Yes  Thur   Lunch     2              6.76
# 144       16.43  2.30  Female     No  Thur   Lunch     2              8.22
# 35        24.06  3.60    Male     No   Sat  Dinner     3              8.02
# 123       15.95  2.00    Male     No  Thur   Lunch     2              7.98
# 61        13.81  2.00    Male    Yes   Sat  Dinner     2              6.90
# 148        9.78  1.73    Male     No  Thur   Lunch     2              4.89
# 233       10.77  1.47    Male     No   Sat  Dinner     2              5.38
# 227       20.45  3.00    Male     No   Sat  Dinner     4              5.11
#
#            Payer Name CC Number Payment ID Fiyat_Kategorisi
# 169          Amy Hill       019    Sat1788               $$
# 162    Jennifer Baird       693    Sun5521               $$
# 199  Joseph Murphy MD       275   Thur2428               $$
# 144       Linda Jones       658   Thur9002               $$
# 35     Joseph Mullins       299     Sat632               $$
# 123  Christopher Lang       319   Thur1992               $$
# 61     Ryan Hernandez       806    Sat3030               $$
# 148     David Stewart       399   Thur7276                $
# 233        Paul Novak       858    Sat1467               $$
# 227    Robert Bradley       910    Sat4319               $$

# %% [markdown]
# ## 3.Yol Vektorized(En Hızlısı)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name CC Number Payment ID Fiyat_Kategorisi
# 0  Christy Cunningham       410    Sun2959               $$
# 1      Douglas Tucker       230    Sun4608               $$
# 2      Travis Walters       322    Sun4458               $$
# 3    Nathaniel Harris       994    Sun5260               $$
# 4        Tonya Carter       221    Sun2251               $$

# %%
df.drop('Fiyat_Kategorisi' , axis = 1 , inplace = True)   #en üstteki fonksiyonu çağırmak yerine Fiyat_Kategori'sini drop ettik

# %%
df['total_bill'].values
# Out:
# array([16.99, 10.34, 21.01, 23.68, 24.59, 25.29,  8.77, 26.88, 15.04,
#        14.78, 10.27, 35.26, 15.42, 18.43, 14.83, 21.58, 10.33, 16.29,
#        16.97, 20.65, 17.92, 20.29, 15.77, 39.42, 19.82, 17.81, 13.37,
#        12.69, 21.7 , 19.65,  9.55, 18.35, 15.06, 20.69, 17.78, 24.06,
#        16.31, 16.93, 18.69, 31.27, 16.04, 17.46, 13.94,  9.68, 30.4 ,
#        18.29, 22.23, 32.4 , 28.55, 18.04, 12.54, 10.29, 34.81,  9.94,
#        25.56, 19.49, 38.01, 26.41, 11.24, 48.27, 20.29, 13.81, 11.02,
#        18.29, 17.59, 20.08, 16.45,  3.07, 20.23, 15.01, 12.02, 17.07,
#        26.86, 25.28, 14.73, 10.51, 17.92, 27.2 , 22.76, 17.29, 19.44,
#        16.66, 10.07, 32.68, 15.98, 34.83, 13.03, 18.28, 24.71, 21.16,
#        28.97, 22.49,  5.75, 16.32, 22.75, 40.17, 27.28, 12.03, 21.01,
#        12.46, 11.35, 15.38, 44.3 , 22.42, 20.92, 15.36, 20.49, 25.21,
#        18.24, 14.31, 14.  ,  7.25, 38.07, 23.95, 25.71, 17.31, 29.93,
#        10.65, 12.43, 24.08, 11.69, 13.42, 14.26, 15.95, 12.48, 29.8 ,
#         8.52, 14.52, 11.38, 22.82, 19.08, 20.27, 11.17, 12.26, 18.26,
#         8.51, 10.33, 14.15, 16.  , 13.16, 17.47, 34.3 , 41.19, 27.05,
#        16.43,  8.35, 18.64, 11.87,  9.78,  7.51, 14.07, 13.13, 17.26,
#        24.55, 19.77, 29.85, 48.17, 25.  , 13.39, 16.49, 21.5 , 12.66,
#        16.21, 13.81, 17.51, 24.52, 20.76, 31.71, 10.59, 10.63, 50.81,
#        15.81,  7.25, 31.85, 16.82, 32.9 , 17.89, 14.48,  9.6 , 34.63,
#        34.65, 23.33, 45.35, 23.17, 40.55, 20.69, 20.9 , 30.46, 18.15,
#        23.1 , 15.69, 19.81, 28.44, 15.48, 16.58,  7.56, 10.34, 43.11,
#        13.  , 13.51, 18.71, 12.74, 13.  , 16.4 , 20.53, 16.47, 26.59,
#        38.73, 24.27, 12.76, 30.06, 25.89, 48.33, 13.27, 28.17, 12.9 ,
#        28.15, 11.59,  7.74, 30.14, 12.16, 13.42,  8.58, 15.98, 13.42,
#        16.27, 10.09, 20.45, 13.28, 22.12, 24.01, 15.69, 11.61, 10.77,
#        15.53, 10.07, 12.6 , 32.83, 35.83, 29.03, 27.18, 22.67, 17.82,
#        18.78])

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name CC Number Payment ID
# 0  Christy Cunningham       410    Sun2959
# 1      Douglas Tucker       230    Sun4608
# 2      Travis Walters       322    Sun4458
# 3    Nathaniel Harris       994    Sun5260
# 4        Tonya Carter       221    Sun2251

# %%
def fiyat_kategori_vectorized(bill):
  categories = np.full_like(bill , '$' , dtype= 'U3')    #Bütün sütunu bill boyutunda $ ile doldurduk(full_like   Tümünü şunun gibi doldur demek.Burada bill boyutunu $ ile doldurduk)

  categories[(bill >= 10) & (bill < 30)] = '$$'   #Bu aralıktaysa $$ ile değiştir

  categories[bill >= 30] = '$$$'    #Bu aralıktaysa $$$ ile değiştir

  return categories   #tüm kategoriyi döndür

# %%
df['Fiyat_Kategorisi'] = fiyat_kategori_vectorized(df['total_bill'])

# %%
df.sample(10)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 200       18.71  4.00    Male    Yes  Thur   Lunch     3              6.24
# 107       25.21  4.29    Male    Yes   Sat  Dinner     2             12.60
# 36        16.31  2.00    Male     No   Sat  Dinner     3              5.44
# 181       23.33  5.65    Male    Yes   Sun  Dinner     2             11.66
# 193       15.48  2.02    Male    Yes  Thur   Lunch     2              7.74
# 100       11.35  2.50  Female    Yes   Fri  Dinner     2              5.68
# 152       17.26  2.74    Male     No   Sun  Dinner     3              5.75
# 179       34.63  3.55    Male    Yes   Sun  Dinner     2             17.32
# 48        28.55  2.05    Male     No   Sun  Dinner     3              9.52
# 129       22.82  2.18    Male     No  Thur   Lunch     3              7.61
#
#            Payer Name CC Number Payment ID Fiyat_Kategorisi
# 200      Jason Conrad       487   Thur6048               $$
# 107      Jason Mullen       868    Sat5196               $$
# 36       William Ford       398    Sat9139               $$
# 181         Jason Cox       223    Sun3402               $$
# 193  Raymond Sullivan       315    Thur606               $$
# 100        Lori Lynch       492    Fri4106               $$
# 152     Gregory Smith       741    Sun5205               $$
# 179      Brian Bailey       848    Sun9851              $$$
# 48      Austin Fisher       587    Sun4142               $$
# 129    Raymond Torres       024   Thur9424               $$

# %% [markdown]
# # .apply() metodu birden fazla sütuna aynı anda uygulanabilir

# %% [markdown]
# ## 1.Yol

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name CC Number Payment ID Fiyat_Kategorisi
# 0  Christy Cunningham       410    Sun2959               $$
# 1      Douglas Tucker       230    Sun4608               $$
# 2      Travis Walters       322    Sun4458               $$
# 3    Nathaniel Harris       994    Sun5260               $$
# 4        Tonya Carter       221    Sun2251               $$

# %%
def kareAl(x):
  return x**2

# %%
# df[['total_bill' , 'tip']] = df[['total_bill' , 'tip']].apply(kareAl)
df[['total_bill' , 'tip']].apply(kareAl)
# Out:
#      total_bill      tip
# 0      288.6601   1.0201
# 1      106.9156   2.7556
# 2      441.4201  12.2500
# 3      560.7424  10.9561
# 4      604.6681  13.0321
# ..          ...      ...
# 239    842.7409  35.0464
# 240    738.7524   4.0000
# 241    513.9289   4.0000
# 242    317.5524   3.0625
# 243    352.6884   9.0000
#
# [244 rows x 2 columns]

# %% [markdown]
# ## 2.Yol

# %%
# df[['total_bill' , 'tip']] = df[['total_bill' , 'tip']].apply(lambda x : x**2)
df[['total_bill' , 'tip']].apply(lambda x : x**2)
# Out:
#      total_bill      tip
# 0      288.6601   1.0201
# 1      106.9156   2.7556
# 2      441.4201  12.2500
# 3      560.7424  10.9561
# 4      604.6681  13.0321
# ..          ...      ...
# 239    842.7409  35.0464
# 240    738.7524   4.0000
# 241    513.9289   4.0000
# 242    317.5524   3.0625
# 243    352.6884   9.0000
#
# [244 rows x 2 columns]

# %% [markdown]
# ## 3.Yol Vektorized(En Hızlısı)

# %%
# df[['total_bill' , 'tip']] = np.square(df[['total_bill' , 'tip']])
np.square(df[['total_bill' , 'tip']])
# Out:
#      total_bill      tip
# 0      288.6601   1.0201
# 1      106.9156   2.7556
# 2      441.4201  12.2500
# 3      560.7424  10.9561
# 4      604.6681  13.0321
# ..          ...      ...
# 239    842.7409  35.0464
# 240    738.7524   4.0000
# 241    513.9289   4.0000
# 242    317.5524   3.0625
# 243    352.6884   9.0000
#
# [244 rows x 2 columns]

# %%
df.describe()   #DataDrame'in özetini yazar
# Out:
#        total_bill         tip        size  price_per_person
# count  244.000000  244.000000  244.000000        244.000000
# mean    19.785943    2.998279    2.569672          7.888197
# std      8.902412    1.383638    0.951100          2.914234
# min      3.070000    1.000000    1.000000          2.880000
# 25%     13.347500    2.000000    2.000000          5.800000
# 50%     17.795000    2.900000    2.000000          7.255000
# 75%     24.127500    3.562500    3.000000          9.390000
# max     50.810000   10.000000    6.000000         20.270000

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name CC Number Payment ID Fiyat_Kategorisi
# 0  Christy Cunningham       410    Sun2959               $$
# 1      Douglas Tucker       230    Sun4608               $$
# 2      Travis Walters       322    Sun4458               $$
# 3    Nathaniel Harris       994    Sun5260               $$
# 4        Tonya Carter       221    Sun2251               $$

# %%
df.sort_values(by= 'total_bill', ascending=True) # ascending = True olduğu için küçükten büyüğe sıraladı.
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 172        7.25   5.15    Male    Yes   Sun  Dinner     2              3.62
# 149        7.51   2.00    Male     No  Thur   Lunch     2              3.76
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3             15.12
# 156       48.17   5.00    Male     No   Sun  Dinner     6              8.03
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
#
#           Payer Name CC Number Payment ID Fiyat_Kategorisi
# 67     Tiffany Brock       267    Sat3455                $
# 92      Leah Ramirez       392    Fri3780                $
# 111      Terri Jones       887    Sat4801                $
# 172      Larry White       103    Sun9209                $
# 149   Daniel Robbins       889   Thur6321                $
# ..               ...       ...        ...              ...
# 182     Jose Parsons       910    Sun2337              $$$
# 156    Ryan Gonzales       321    Sun7518              $$$
# 59       Brian Ortiz       595    Sat8139              $$$
# 212  Alex Williamson       212    Sat4590              $$$
# 170    Gregory Clark       236    Sat1954              $$$
#
# [244 rows x 12 columns]

# %%
df.sort_values('total_bill' , ascending = False , inplace = True)   #Büyükten küçüğe sıraladı ve bunu kalıcı hale getirdim

# %%
df.head()
# Out:
#      total_bill    tip   sex smoker  day    time  size  price_per_person  \
# 170       50.81  10.00  Male    Yes  Sat  Dinner     3             16.94
# 212       48.33   9.00  Male     No  Sat  Dinner     4             12.08
# 59        48.27   6.73  Male     No  Sat  Dinner     4             12.07
# 156       48.17   5.00  Male     No  Sun  Dinner     6              8.03
# 182       45.35   3.50  Male    Yes  Sun  Dinner     3             15.12
#
#           Payer Name CC Number Payment ID Fiyat_Kategorisi
# 170    Gregory Clark       236    Sat1954              $$$
# 212  Alex Williamson       212    Sat4590              $$$
# 59       Brian Ortiz       595    Sat8139              $$$
# 156    Ryan Gonzales       321    Sun7518              $$$
# 182     Jose Parsons       910    Sun2337              $$$

# %%
df.reset_index(inplace = True , drop = True)    #index'i resetleyip sıraladı

# %%
df.head()
# Out:
#    total_bill    tip   sex smoker  day    time  size  price_per_person  \
# 0       50.81  10.00  Male    Yes  Sat  Dinner     3             16.94
# 1       48.33   9.00  Male     No  Sat  Dinner     4             12.08
# 2       48.27   6.73  Male     No  Sat  Dinner     4             12.07
# 3       48.17   5.00  Male     No  Sun  Dinner     6              8.03
# 4       45.35   3.50  Male    Yes  Sun  Dinner     3             15.12
#
#         Payer Name CC Number Payment ID Fiyat_Kategorisi
# 0    Gregory Clark       236    Sat1954              $$$
# 1  Alex Williamson       212    Sat4590              $$$
# 2      Brian Ortiz       595    Sat8139              $$$
# 3    Ryan Gonzales       321    Sun7518              $$$
# 4     Jose Parsons       910    Sun2337              $$$

# %%
df.sort_values(['tip' , 'total_bill'] , ascending = False)   #ilk önce tip'e göre sırala sonra total_bill'e göre sırala. Büyükten küçüğe sıralar ascending = False olduğundan dolayı
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 0         50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# 1         48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 10        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 2         48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 20        34.30   6.70    Male     No  Thur   Lunch     6              5.72
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 131       16.99   1.01  Female     No   Sun  Dinner     2              8.49
# 195       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
# 240        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 242        5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
# 243        3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
#
#              Payer Name CC Number Payment ID Fiyat_Kategorisi
# 0         Gregory Clark       236    Sat1954              $$$
# 1       Alex Williamson       212    Sat4590              $$$
# 10       Lance Peterson       808     Sat239              $$$
# 2           Brian Ortiz       595    Sat8139              $$$
# 20       Steven Carlson       508   Thur1025              $$$
# ..                  ...       ...        ...              ...
# 131  Christy Cunningham       410    Sun2959               $$
# 195       Matthew Myers       965    Sat5032               $$
# 240         Terri Jones       887    Sat4801                $
# 242        Leah Ramirez       392    Fri3780                $
# 243       Tiffany Brock       267    Sat3455                $
#
# [244 rows x 12 columns]

# %%
df.head(10)
# Out:
#    total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 0       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# 1       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 2       48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 3       48.17   5.00    Male     No   Sun  Dinner     6              8.03
# 4       45.35   3.50    Male    Yes   Sun  Dinner     3             15.12
# 5       44.30   2.50  Female    Yes   Sat  Dinner     3             14.77
# 6       43.11   5.00  Female    Yes  Thur   Lunch     4             10.78
# 7       41.19   5.00    Male     No  Thur   Lunch     5              8.24
# 8       40.55   3.00    Male    Yes   Sun  Dinner     2             20.27
# 9       40.17   4.73    Male    Yes   Fri  Dinner     4             10.04
#
#         Payer Name CC Number Payment ID Fiyat_Kategorisi
# 0    Gregory Clark       236    Sat1954              $$$
# 1  Alex Williamson       212    Sat4590              $$$
# 2      Brian Ortiz       595    Sat8139              $$$
# 3    Ryan Gonzales       321    Sun7518              $$$
# 4     Jose Parsons       910    Sun2337              $$$
# 5    Heather Cohen       604    Sat6240              $$$
# 6      Brooke Soto       175   Thur9313              $$$
# 7     Eric Andrews       453   Thur3621              $$$
# 8      Stephen Cox       029    Sun5140              $$$
# 9    Aaron Bentley       690    Fri9628              $$$

# %%
df['price_per_person'].max()   #max eleman
# Out:
# 20.27

# %%
df['price_per_person'].argmax()   #max elemanın indexi
# Out:
# np.int64(8)

# %%
df['price_per_person'].idxmax()   #max elemanın indexi
# Out:
# 8

# %%
df.head()
# Out:
#    total_bill    tip   sex smoker  day    time  size  price_per_person  \
# 0       50.81  10.00  Male    Yes  Sat  Dinner     3             16.94
# 1       48.33   9.00  Male     No  Sat  Dinner     4             12.08
# 2       48.27   6.73  Male     No  Sat  Dinner     4             12.07
# 3       48.17   5.00  Male     No  Sun  Dinner     6              8.03
# 4       45.35   3.50  Male    Yes  Sun  Dinner     3             15.12
#
#         Payer Name CC Number Payment ID Fiyat_Kategorisi
# 0    Gregory Clark       236    Sat1954              $$$
# 1  Alex Williamson       212    Sat4590              $$$
# 2      Brian Ortiz       595    Sat8139              $$$
# 3    Ryan Gonzales       321    Sun7518              $$$
# 4     Jose Parsons       910    Sun2337              $$$

# %%
df.corr(numeric_only=True) # Makine öğrenmesi modelleri kurarken hayati öneme sahip.
                           # Numeric columnlar arasındaki doğrusal ilişkileri gösteriyor.
# Out:
#                   total_bill       tip      size  price_per_person
# total_bill          1.000000  0.675734  0.598315          0.647554
# tip                 0.675734  1.000000  0.489299          0.347405
# size                0.598315  0.489299  1.000000         -0.175359
# price_per_person    0.647554  0.347405 -0.175359          1.000000

# %%
df['sex'].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
df.day.value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
df.day.unique()   #day'in içinde 4 farklı değer var
# Out:
# array(['Sat', 'Sun', 'Thur', 'Fri'], dtype=object)

# %%
df.day.nunique() #kaç farklı unique değer var
# Out:
# 4

# %%
len(df.day.unique())
# Out:
# 4

# %%
# Amaç : sex column'undaki Male olanları 'M' , Female olanları 'F' haline getirmek.

# %% [markdown]
# ## 1.Yol (.apply() metodu ile)

# %%
df.head()
# Out:
#    total_bill    tip   sex smoker  day    time  size  price_per_person  \
# 0       50.81  10.00  Male    Yes  Sat  Dinner     3             16.94
# 1       48.33   9.00  Male     No  Sat  Dinner     4             12.08
# 2       48.27   6.73  Male     No  Sat  Dinner     4             12.07
# 3       48.17   5.00  Male     No  Sun  Dinner     6              8.03
# 4       45.35   3.50  Male    Yes  Sun  Dinner     3             15.12
#
#         Payer Name CC Number Payment ID Fiyat_Kategorisi
# 0    Gregory Clark       236    Sat1954              $$$
# 1  Alex Williamson       212    Sat4590              $$$
# 2      Brian Ortiz       595    Sat8139              $$$
# 3    Ryan Gonzales       321    Sun7518              $$$
# 4     Jose Parsons       910    Sun2337              $$$

# %%
df['sex'] = df['sex'].apply(lambda x : 'M' if x == 'Male' else 'F')

# %%
df.head()
# Out:
#    total_bill    tip sex smoker  day    time  size  price_per_person  \
# 0       50.81  10.00   M    Yes  Sat  Dinner     3             16.94
# 1       48.33   9.00   M     No  Sat  Dinner     4             12.08
# 2       48.27   6.73   M     No  Sat  Dinner     4             12.07
# 3       48.17   5.00   M     No  Sun  Dinner     6              8.03
# 4       45.35   3.50   M    Yes  Sun  Dinner     3             15.12
#
#         Payer Name CC Number Payment ID Fiyat_Kategorisi
# 0    Gregory Clark       236    Sat1954              $$$
# 1  Alex Williamson       212    Sat4590              $$$
# 2      Brian Ortiz       595    Sat8139              $$$
# 3    Ryan Gonzales       321    Sun7518              $$$
# 4     Jose Parsons       910    Sun2337              $$$

# %% [markdown]
# ## 2.Yol (.replace() Metodu ile)

# %%
df.head()
# Out:
#    total_bill    tip sex smoker  day    time  size  price_per_person  \
# 0       50.81  10.00   M    Yes  Sat  Dinner     3             16.94
# 1       48.33   9.00   M     No  Sat  Dinner     4             12.08
# 2       48.27   6.73   M     No  Sat  Dinner     4             12.07
# 3       48.17   5.00   M     No  Sun  Dinner     6              8.03
# 4       45.35   3.50   M    Yes  Sun  Dinner     3             15.12
#
#         Payer Name CC Number Payment ID Fiyat_Kategorisi
# 0    Gregory Clark       236    Sat1954              $$$
# 1  Alex Williamson       212    Sat4590              $$$
# 2      Brian Ortiz       595    Sat8139              $$$
# 3    Ryan Gonzales       321    Sun7518              $$$
# 4     Jose Parsons       910    Sun2337              $$$

# %%
df['sex'].replace('Female' , 'F' , inplace = True)
df['sex'].replace('Male' , 'M' , inplace = True)
# Out:
# <ipython-input-58-41937179088f>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['sex'].replace('Female' , 'F' , inplace = True)
# <ipython-input-58-41937179088f>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['sex'].replace('Male' , 'M' , inplace = True)

# %%
df.head()
# Out:
#    total_bill    tip sex smoker  day    time  size  price_per_person  \
# 0       50.81  10.00   M    Yes  Sat  Dinner     3             16.94
# 1       48.33   9.00   M     No  Sat  Dinner     4             12.08
# 2       48.27   6.73   M     No  Sat  Dinner     4             12.07
# 3       48.17   5.00   M     No  Sun  Dinner     6              8.03
# 4       45.35   3.50   M    Yes  Sun  Dinner     3             15.12
#
#         Payer Name CC Number Payment ID Fiyat_Kategorisi
# 0    Gregory Clark       236    Sat1954              $$$
# 1  Alex Williamson       212    Sat4590              $$$
# 2      Brian Ortiz       595    Sat8139              $$$
# 3    Ryan Gonzales       321    Sun7518              $$$
# 4     Jose Parsons       910    Sun2337              $$$

# %%
df['sex'].replace(['Female' , 'Male'] , ['F' , 'M'])   #üstteki örneğin tek satırda yapılmış hali
# Out:
# 0      M
# 1      M
# 2      M
# 3      M
# 4      M
#       ..
# 239    M
# 240    F
# 241    M
# 242    F
# 243    F
# Name: sex, Length: 244, dtype: object

# %% [markdown]
# ## 3.Yol (.map() metodu ile)

# %%
df['sex'].map({'Female' : 'F' ,
               'Male' : 'M'})
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 239    NaN
# 240    NaN
# 241    NaN
# 242    NaN
# 243    NaN
# Name: sex, Length: 244, dtype: object

# %% [markdown]
# --------------------
# pandas 4

# %%
simple_df = pd.DataFrame( data = [[1,2,2,2] , [1,2,3,4] , [1,2,2,2] , [1,2,2,2] ], index = ['a','b','c','d'] , columns = ['col1','col2','col3','col4'])
simple_df
# Out:
#    col1  col2  col3  col4
# a     1     2     2     2
# b     1     2     3     4
# c     1     2     2     2
# d     1     2     2     2

# %%
simple_df.duplicated()   #duplicated kopya veri demek. Kopya veriler genelde hatadan kaynaklanıyor.
#ilk önce a'ya baktı daha önceden yazılmış kopyası var mı yok o yüzden false yazdı. Sonra b'ye baktı daha önceden yazılmış kopyası var mı yok o zmn false yazdı.
#Sonra c'ye batı daha önce kopyası var mı var o zaman true yazdı. Daha sonra d'ye baktı daha önceden yazılmış kopyası var mı var o zaman true yazdı.
# Out:
# a    False
# b    False
# c     True
# d     True
# dtype: bool

# %%
simple_df.drop_duplicates()  #duplicated olanları düşür demek. Yani c ve d silinir. Fakat kalıcı olarak silmedim.(inplace = True yazmadım)
#c ve d a'nın duplicated'i olduğu için düşürüldü default değerden dolayı. Fakat biz keep ile istediğimizi yazar veya hepsini düşürebiliriz.
# Out:
#    col1  col2  col3  col4
# a     1     2     2     2
# b     1     2     3     4

# %%
df.head()
# Out:
#    total_bill    tip sex smoker  day    time  size  price_per_person  \
# 0       50.81  10.00   M    Yes  Sat  Dinner     3             16.94
# 1       48.33   9.00   M     No  Sat  Dinner     4             12.08
# 2       48.27   6.73   M     No  Sat  Dinner     4             12.07
# 3       48.17   5.00   M     No  Sun  Dinner     6              8.03
# 4       45.35   3.50   M    Yes  Sun  Dinner     3             15.12
#
#         Payer Name CC Number Payment ID Fiyat_Kategorisi
# 0    Gregory Clark       236    Sat1954              $$$
# 1  Alex Williamson       212    Sat4590              $$$
# 2      Brian Ortiz       595    Sat8139              $$$
# 3    Ryan Gonzales       321    Sun7518              $$$
# 4     Jose Parsons       910    Sun2337              $$$

# %%
# Amaç : total_bill değeri 10 ile 20 arasındaki satırları getirin.

# %%
df[10 < df['total_bill'] < 20] # Bu şekilde sorgu yapamıyoruz. Bunun için .between() methodu var.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-44686b75bbd8> in <cell line: 0>()
# ----> 1 df[10 < df['total_bill'] < 20] # Bu şekilde sorgu yapamıyoruz. Bunun için .between() methodu var.
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __nonzero__(self)
#    1575     @final
#    1576     def __nonzero__(self) -> NoReturn:
# -> 1577         raise ValueError(
#    1578             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1579             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df[df['total_bill'].between(10,20)] # Default ayarlarda inclusive = 'both' dur. Yani iki taraf da dahildir.
# Out:
#      total_bill   tip sex smoker   day    time  size  price_per_person  \
# 97        19.82  3.18   M     No   Sat  Dinner     2              9.91
# 98        19.81  4.19   F    Yes  Thur   Lunch     2              9.90
# 99        19.77  2.00   M     No   Sun  Dinner     4              4.94
# 100       19.65  3.00   F     No   Sat  Dinner     2              9.82
# 101       19.49  3.51   M     No   Sun  Dinner     2              9.74
# ..          ...   ...  ..    ...   ...     ...   ...               ...
# 222       10.29  2.60   F     No   Sun  Dinner     2              5.14
# 223       10.27  1.71   M     No   Sun  Dinner     2              5.14
# 224       10.09  2.00   F    Yes   Fri   Lunch     2              5.04
# 225       10.07  1.25   M     No   Sat  Dinner     2              5.04
# 226       10.07  1.83   F     No  Thur   Lunch     1             10.07
#
#            Payer Name CC Number Payment ID Fiyat_Kategorisi
# 97   Christopher Ross       928    Sat6236               $$
# 98        Kristy Boyd       068    Thur967               $$
# 99        James Smith       229    Sun5814               $$
# 100    Melinda Murphy       051    Sat2467               $$
# 101  Michael Hamilton       768    Sun1118               $$
# ..                ...       ...        ...              ...
# 222    Jessica Ibarra       713    Sun4474               $$
# 223     William Riley       219    Sun2546               $$
# 224        Ruth Weiss       635    Fri6359               $$
# 225     Sean Gonzalez       605    Sat4615               $$
# 226       Julie Moody       843   Thur4909               $$
#
# [130 rows x 12 columns]

# %%
df[df['total_bill'].between(10,20 , inclusive = 'left')]   #sol dahil. Yani [10,20), right yazsaydık (10,20] olurdu.
# Out:
#      total_bill   tip sex smoker   day    time  size  price_per_person  \
# 97        19.82  3.18   M     No   Sat  Dinner     2              9.91
# 98        19.81  4.19   F    Yes  Thur   Lunch     2              9.90
# 99        19.77  2.00   M     No   Sun  Dinner     4              4.94
# 100       19.65  3.00   F     No   Sat  Dinner     2              9.82
# 101       19.49  3.51   M     No   Sun  Dinner     2              9.74
# ..          ...   ...  ..    ...   ...     ...   ...               ...
# 222       10.29  2.60   F     No   Sun  Dinner     2              5.14
# 223       10.27  1.71   M     No   Sun  Dinner     2              5.14
# 224       10.09  2.00   F    Yes   Fri   Lunch     2              5.04
# 225       10.07  1.25   M     No   Sat  Dinner     2              5.04
# 226       10.07  1.83   F     No  Thur   Lunch     1             10.07
#
#            Payer Name CC Number Payment ID Fiyat_Kategorisi
# 97   Christopher Ross       928    Sat6236               $$
# 98        Kristy Boyd       068    Thur967               $$
# 99        James Smith       229    Sun5814               $$
# 100    Melinda Murphy       051    Sat2467               $$
# 101  Michael Hamilton       768    Sun1118               $$
# ..                ...       ...        ...              ...
# 222    Jessica Ibarra       713    Sun4474               $$
# 223     William Riley       219    Sun2546               $$
# 224        Ruth Weiss       635    Fri6359               $$
# 225     Sean Gonzalez       605    Sat4615               $$
# 226       Julie Moody       843   Thur4909               $$
#
# [130 rows x 12 columns]

# %%
df.nlargest(5 , 'tip')     # nlargest en büyük değerleri yazar.
# Out:
#     total_bill    tip sex smoker   day    time  size  price_per_person  \
# 0        50.81  10.00   M    Yes   Sat  Dinner     3             16.94
# 1        48.33   9.00   M     No   Sat  Dinner     4             12.08
# 10       39.42   7.58   M     No   Sat  Dinner     4              9.86
# 2        48.27   6.73   M     No   Sat  Dinner     4             12.07
# 20       34.30   6.70   M     No  Thur   Lunch     6              5.72
#
#          Payer Name CC Number Payment ID Fiyat_Kategorisi
# 0     Gregory Clark       236    Sat1954              $$$
# 1   Alex Williamson       212    Sat4590              $$$
# 10   Lance Peterson       808     Sat239              $$$
# 2       Brian Ortiz       595    Sat8139              $$$
# 20   Steven Carlson       508   Thur1025              $$$

# %%
df.sort_values('tip' , ascending= False).head(5)  #nlargest kullanmadan yazdırma -> df'i tip'e göre sort ettik, ascending ile büyükten küçüğe yazdırdık, head ile ilk kaç eleman almak istedğimizi yazdık
# Out:
#     total_bill    tip sex smoker   day    time  size  price_per_person  \
# 0        50.81  10.00   M    Yes   Sat  Dinner     3             16.94
# 1        48.33   9.00   M     No   Sat  Dinner     4             12.08
# 10       39.42   7.58   M     No   Sat  Dinner     4              9.86
# 2        48.27   6.73   M     No   Sat  Dinner     4             12.07
# 20       34.30   6.70   M     No  Thur   Lunch     6              5.72
#
#          Payer Name CC Number Payment ID Fiyat_Kategorisi
# 0     Gregory Clark       236    Sat1954              $$$
# 1   Alex Williamson       212    Sat4590              $$$
# 10   Lance Peterson       808     Sat239              $$$
# 2       Brian Ortiz       595    Sat8139              $$$
# 20   Steven Carlson       508   Thur1025              $$$

# %%
df.nsmallest(columns= ['tip','total_bill'] , n = 3)   #tip ve total_bill'in en küçük 3 elemanını yazdırma
# Out:
#      total_bill  tip sex smoker  day    time  size  price_per_person  \
# 243        3.07  1.0   F    Yes  Sat  Dinner     1              3.07
# 242        5.75  1.0   F    Yes  Fri  Dinner     2              2.88
# 240        7.25  1.0   F     No  Sat  Dinner     1              7.25
#
#         Payer Name CC Number Payment ID Fiyat_Kategorisi
# 243  Tiffany Brock       267    Sat3455                $
# 242   Leah Ramirez       392    Fri3780                $
# 240    Terri Jones       887    Sat4801                $

# %%
#Yasin
